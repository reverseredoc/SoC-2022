# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd
from sklearn import datasets,linear_model
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
data1=pd.read_csv(r"/home/user/Downloads/weatherHistory.csv")#r is for raw string 
df=pd.DataFrame(data1)
df.head(n=6) # 6 rows printed out
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
#
# ...

# %%
x=df.drop('Humidity',1)#dropped from x axis
y=df['Humidity']# Humidity is y our dependent variable 
df=df.drop(['Formatted Date','Summary','Precip Type','Loud Cover','Daily Summary','Apparent Temperature (C)','Visibility (km)','Wind Bearing (degrees)','Wind Speed (km/h)','Humidity','Pressure (millibars)'],axis=1)
# Out:
# /tmp/ipykernel_25631/1748118468.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x=df.drop('Humidity',1)#dropped from x axis

# %%
df.head(n=5)
# Out:
#    Temperature (C)
# 0         9.472222
# 1         9.355556
# 2         9.377778
# 3         8.288889
# 4         8.755556

# %%
#create test and train variables using test_train_split from sklearn library
x_train,x_test,y_train,y_test=train_test_split(df,y,test_size=0.25)
lrm=linear_model.LinearRegression()
lrm_model=lrm.fit(x_train,y_train)
lrm_predictions=lrm.predict(x_test)
#plotting the prdictions with a scatter plot
plt.scatter(y_test,lrm_predictions)
plt.title("Plot of predicted versus Actual Values")
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
print('Score:',lrm_model.score(x_test,y_test))
# Out:
# Score: 0.39695615637962056
